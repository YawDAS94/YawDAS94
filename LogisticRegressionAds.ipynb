# %% [markdown]
# <h1><b>Yaw's Logistic Regression Project - Ad Data</b></h1>
#
# <h2><b>What This Model Showcases:</b></h2>
# <ul>
#     <li>This project demonstrates my skills in logistic regression, data interpretation, and feature engineering to significantly improve model performance in predicting whether a user would click on an ad.</li>
#     <li>I showcased strong model evaluation abilities, including precision, recall, and F1-score analysis, to ensure accurate and reliable predictions.</li>
#     <li>I also exhibited problem-solving skills by iterating on the model and employing data-driven techniques to achieve a marked improvement in accuracy, which is critical for optimizing ad targeting and making informed marketing decisions.</li>
# </ul>
#
# <h2><b>Results:</b></h2>
# <ul>
#     <li><b>Precision:</b>
#         <ul>
#             <li>10% increase for predicting if a user won’t click the ad.</li>
#             <li>3% increase for predicting if a user will click the ad.</li>
#         </ul>
#     </li>
#     <li><b>Recall:</b>
#         <ul>
#             <li>2% increase for correctly identifying when a user did not click on an ad.</li>
#             <li>12% increase for correctly identifying when a user did click on an ad.</li>
#         </ul>
#     </li>
#     <li><b>Accuracy:</b> 7% improvement overall.</li>
# </ul>
#
# <h2><b>Project Overview:</b></h2>
# <p>
# I'll be working with advertising data to determine whether a person on the internet clicked on an advertisement on a company website. The goal is to build a model that predicts whether the person will click on the ad based on user features.
# </p>
#
# <h3><b>Dataset Features:</b></h3>
# <ul>
#     <li><b>Daily Time Spent on Site:</b> Consumer time spent on site in minutes.</li>
#     <li><b>Age:</b> The age of the consumer.</li>
#     <li><b>Area Income:</b> The average income of the consumer's area.</li>
#     <li><b>Ad Topic Line:</b> The headline of the ad.</li>
#     <li><b>City:</b> The city where the consumer is located.</li>
#     <li><b>Male:</b> Whether the consumer is male or not.</li>
#     <li><b>Country:</b> The country where the consumer is located.</li>
#     <li><b>Timestamp:</b> The time at which the consumer clicked on the ad or closed the window.</li>
#     <li><b>Clicked on Ad:</b> A binary indicator (0 or 1) of whether the user clicked on the ad.</li>
# </ul>

# %% [markdown]
# <h1><b> Import Libaries </b></h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h1><b> Get the Data </b></h1>

# %%
ad_data = pd.read_csv('advertising.csv')

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %% [markdown]
# <h1><b> Description of Data </b></h1>

# %% [markdown]
# By looking at the dataset, the average time spent on site is 65 minutes, + or - 16 minutes
# Average age is 36 years old, and makes $55K.
# The average person spends 3 hours on the internet.
# Roughly half the people are male
# Half the people click on an add

# %% [markdown]
# <h1><b> Exploratory Data Analysis </b></h1>

# %%
sns.set_style('whitegrid')
ad_data['Daily Time Spent on Site'].hist(bins=25)
plt.xlabel('Daily Time Spent on Site')
#histogram on time spent
# Out:
# Text(0.5, 0, 'Daily Time Spent on Site')

# %%
sns.jointplot(x="Area Income", y="Daily Internet Usage", data=ad_data) #not much correlation between income and daily internet usage

# %% [markdown]
# <h1><b> Logistic Regression </b></h1>

# %%
from sklearn.model_selection import train_test_split

# %%
x = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage', 'Male']]
y = ad_data['Clicked on Ad']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .33, random_state=42)

# %%
#traina nd fit a logistic regression model

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(x_train, y_train)
# Out:
# C:\Users\yawmo\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = logmodel.predict(x_test)

# %% [markdown]
# #make a classification report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       162
#            1       0.95      0.85      0.90       168
#
#     accuracy                           0.90       330
#    macro avg       0.91      0.90      0.90       330
# weighted avg       0.91      0.90      0.90       330

# %% [markdown]
# <h1><b>Conclusions from Logistic Regression </b></h1>

# %% [markdown]
# Predicion:
# - Out of all the times I predicted that a user wouldn't click on the ad (0), 86% of those predictions were accurate
# - For all the times I predicted that a user would click on an ad (1), the predictions were accurate 95% of the time
#
# The model is better at predicting when someone clicks on an ad than someone not
#
# Recall:
# - Out of all the instances where the user did not click on the ad (0), my model accurately identified 96% of them
# - Out of all the instances that the user did click on an add, my model identified 85% of them
#
# The model is better at identifying when soemoen doesn't click on the ad, but not as accruate at identifying when someone doesn't
#
# F-1 score:
# When we look at the harmonic mean of precision and recall. We get a 91% for predicting when someone wouldn't click on an ad and 90% when predicting someone would click on an ad
#
# Accruacy:
# Overall Accuracy is 90%

# %% [markdown]
# <h1><b>Boosting Model Accuracy from 90% to 96%!</b></h1>

# %% [markdown]
# <h2><b>Feature Engineering</b></h2>

# %% [markdown]
# <h2><b> Why I am Feature Engineering with interaction terms</b></h2>
# <b> I am making a new variable called time age interaction. The purpose of me making this variable is to capture the combined effect of two variables (age and time spent on site) to see if the new combined variable jointly influences the target varaible (clicked on ad) in a way that's not capturred by each variable independently
#
# By making an interaction term, I am allowing the model to consider the possibiltiy that the impact of one variable on the target variable changes depending on the level with the other. So maybe time spent matters depeneding on how old the user is. Or maybe the age only matters when considering it with time spent. With the interaction varialbe, I can now see how time spent affects across different age groups.
#
# For example:
# If I have two users:
# User A: Age 25, daily time spent  = 100
# User B: Age 60, daily time spent = 100
#
# without the interaction term, the model might predict the same likelihood of clicking on an ad for both users, if all variables are the same. However, maybe younger users like User A might be more likely to click on ads when they spend a lot of time on the site, while older users (like User b0 might be less influenced by time spent. Maybe the relationship is non linear, so interaction terms are user.
#
# I think the only concern I may have about feature engineering is overfitting, where adding interaction terms increases complexity of the model which may lead to overfitting with this limited data. I will cross validate afterwards to valdiate the model's performance.
#
# </b>

# %%
ad_data['Time_Age_Interaction'] = ad_data['Daily Time Spent on Site'] * ad_data['Age']

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad  Time_Age_Interaction
# ...

# %%
x2 = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage', 'Male','Time_Age_Interaction' ]]
y2 = ad_data['Clicked on Ad']

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(x2,y2, test_size = .33, random_state=42)

# %%
logmodel2 = LogisticRegression()

# %%
logmodel2.fit(x2_train, y2_train)
# Out:
# C:\Users\yawmo\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions2 = logmodel2.predict(x2_test)

# %%
print(classification_report(y2_test,predictions2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       162
#            1       0.98      0.95      0.96       168
#
#     accuracy                           0.96       330
#    macro avg       0.96      0.96      0.96       330
# weighted avg       0.96      0.96      0.96       330

# %% [markdown]
# <h2><b>Conclusion from Feature Engineering</b></h2>
# <b> The model is much better! Accuracy improved from 90% to 96%!
# Adding age, time spent interaction improved precision for not clicking the ad from 86% to 95%
#     in addition, it imporved the probability of clicking the ad from 95% to 98%
#     This shows that the second model is much better at correctly identifying both cases with fewer false positives
#
# Recall also jumped from 96% to 98% for not clicking the ad, and jumped from 85% to 95% for clicking on ads
# This shows the 2nd model is better at identifying actual positives for both cases, with fewer false negatives!
#
# The second model is more accruate and reliable across all evalauted metrics.
#
# I could go even further with more feature engineeering, a better model, or hyperparameter tuning, but
# it's diminishing returns at that point.
# </b>

# %%
single_observation = x_test.iloc[0]  # Extract the first observation

# %%
single_observation
# Out:
# Daily Time Spent on Site       63.26
# Age                            29.00
# Area Income                 54787.37
# Daily Internet Usage          120.46
# Male                            1.00
# Name: 521, dtype: float64

# %% [markdown]
# <h3><b> We have a 29 year old male, who spends 2 hours on the internet who makes $55K a year. He spent 63 minutes on the site
# </b></h3>

# %%
#reshape the observation into a 2D array input
single_observation = single_observation.values.reshape(1, -1)

# %%
single_prediction_proba = logmodel.predict_proba(single_observation)
# Out:
# C:\Users\yawmo\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
single_prediction_proba
# Out:
# array([[0.41347655, 0.58652345]])

# %% [markdown]
# <h3><b> The model says this individual has a 41% chance of not clicking the ad,
# and a 59% chance of clicking on the ad
# </b></h3>

# %%
single_observation_result = y_test.iloc[0]

# %%
single_observation_result
# Out:
# 1

# %% [markdown]
# <h3><b> In actuality, the person didn't click the ad, the model was right
# </b></h3>

# %%
single_observation2 = x2_test.iloc[0]  # Extract the first observation

# %%
single_observation2
# Out:
# Daily Time Spent on Site       63.26
# Age                            29.00
# Area Income                 54787.37
# Daily Internet Usage          120.46
# Male                            1.00
# Time_Age_Interaction         1834.54
# Name: 521, dtype: float64

# %%
single_observation2 = single_observation2.reshape(1, -1)

# %%
single_prediction_proba2 = logmodel2.predict_proba(single_observation2)
# Out:
# C:\Users\yawmo\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
single_prediction_proba2
# Out:
# array([[0.01285592, 0.98714408]])

# %% [markdown]
# <h3><b> The previous model was 60% certain that the user wouldn't click on the ad, and accurately predicted the outcome.
# This improved model is 99% certain that the user will click on the ad, and again, the model accurately predicted the outcome.
# </h3></b>
